# %%
import pandas as pd
import csv

# %%
busan_fun = pd.read_csv('./소상공인시장진흥공단_상가(상권)정보_부산_202009.csv', encoding='UTF-8', sep='|')

# %%
busan_fun.loc[busan_fun["상권업종중분류명"].str.contains("PC/오락/당구/볼링등", na=False)]
# Out:
#           상가업소번호        상호명  지점명 상권업종대분류코드  상권업종대분류명 상권업종중분류코드      상권업종중분류명  \
# 128     22226312      유나당구장  NaN         N  관광/여가/오락       N01  PC/오락/당구/볼링등
# 239     23335186       유성기원  NaN         N  관광/여가/오락       N01  PC/오락/당구/볼링등
# 323     21061859       PC허준  NaN         N  관광/여가/오락       N01  PC/오락/당구/볼링등
# 812     20833326       피씨마루  NaN         N  관광/여가/오락       N01  PC/오락/당구/볼링등
# 835     21062934      황금당구장  NaN         N  관광/여가/오락       N01  PC/오락/당구/볼링등
# ...          ...        ...  ...       ...       ...       ...           ...
# 152066  16763649      라이킷PC  만덕점         N  관광/여가/오락       N01  PC/오락/당구/볼링등
# 152130  16741617    오엑스피시감전  시장점         N  관광/여가/오락       N01  PC/오락/당구/볼링등
# 152131  16740676  아이센스리그PC방  초읍점         N  관광/여가/오락       N01  PC/오락/당구/볼링등
# 153542  16698691     스마일pc방  NaN         N  관광/여가/오락       N01  PC/오락/당구/볼링등
# 153543  16698631    장동민의옹피씨  아망떼         N  관광/여가/오락       N01  PC/오락/당구/볼링등
#
#        상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호     건물명  \
# 128       N01A03      당구장   R91135  ...  2647010100100420026011152     NaN
# 239       N01A09       기원   R91293  ...  2623010300102620001004035     NaN
# 323       N01A01   인터넷PC방   R91222  ...  2635010700114290001020163   신도시시장
# 812       N01A01   인터넷PC방   R91222  ...  2638010100105860046001837     NaN
# 835       N01A03      당구장   R91135  ...  2623010900109840000000001     NaN
# ...          ...      ...      ...  ...                        ...     ...
# 152066    N01A01   인터넷PC방   R91222  ...  2632010300108300010005447     NaN
# 152130    N01A01   인터넷PC방   R91222  ...  2653010500101210097007423     NaN
# 152131    N01A01   인터넷PC방   R91222  ...  2623010700102920004027286    성림빌딩
# 153542    N01A01   인터넷PC방   R91222  ...  2611012000100930004000651     NaN
# 153543    N01A01   인터넷PC방   R91222  ...  2635010100102500696012412  돼지만물수퍼
#
#                           도로명주소   구우편번호    신우편번호  동정보  층정보  호정보          경도  \
# 128         부산광역시 연제구 명륜로2번길 32  611800  47514.0  NaN  NaN  NaN  129.080513
# 239        부산광역시 부산진구 새싹로8번길 19  614030  47254.0  NaN    4  NaN  129.059302
# 323          부산광역시 해운대구 좌동로 152  612030  48108.0  NaN  NaN  NaN  129.181141
# 812         부산광역시 사하구 괴정로 169-1  604813  49399.0  NaN    1  NaN  128.980302
# 835      부산광역시 부산진구 가야대로703번길 6  614100  47261.0  NaN    4  NaN  129.048653
# ...                         ...     ...      ...  ...  ...  ...         ...
# 152066         부산광역시 북구 만덕1로 11  616828  46561.0  NaN    4    3  129.036178
# 152130        부산광역시 사상구 괘감로 100  617800  46981.0  NaN    1  NaN  128.985307
# 152131     부산광역시 부산진구 새싹로 285-1  614872  47104.0  NaN  NaN  NaN  129.046866
# 153542      부산광역시 중구 대청로53번길 15  600802  48962.0  NaN    2  NaN  129.025610
# 153543  부산광역시 해운대구 아랫반송로59번길 45  612802  48019.0  NaN    2  NaN  129.152087
#
#                위도
# 128     35.194546
# 239     35.159354
# 323     35.174885
# 812     35.098489
# 835     35.157409
# ...           ...
# 152066  35.213989
# 152130  35.157103
# 152131  35.181564
# 153542  35.103694
# 153543  35.223496
#
# [1409 rows x 39 columns]
