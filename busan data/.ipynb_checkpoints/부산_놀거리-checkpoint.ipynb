# %%
import pandas as pd
import csv

# %% [markdown]
# # PC방

# %%
busan_PCroom = pd.read_csv('부산광역시 금정구_PC방 현황_20200925.csv', encoding='euc-kr' )
busan_PCroom.rename({'상호':'name', '영업소소재지(도로명)':'addr','전화번호':'' }, axis='columns', inplace=True)
busan_PCroom
# Out:
#                    업소명                                            소재지  \
# 0                카오 PC                         부산광역시 금정구 서동로 105 (서동)
# 1                123PC                     부산광역시 금정구 동부곡로10번길 1 (부곡동)
# 2                애플PC방                      부산광역시 금정구 중앙대로 2035 (남산동)
# 3                쿠치나PC                     부산광역시 금정구 서동로149번길 16 (서동)
# 4                쿠키PC방                    부산광역시 금정구 구서로 2 (구서동, 정우빌딩)
# 5               렉없넷pc방                     부산광역시 금정구 금정로149번길 8 (장전동)
# 6                 앤PC방                       부산광역시 금정구 부산대학로 59 (장전동)
# 7        OX PC방 부산대2호점                 부산광역시 금정구 금정로68번길 22, 3층 (장전동)
# 8              아이파크PC방                  부산광역시 금정구 중앙대로1719번길 23 (부곡동)
# 9              사이버존PC방                     부산광역시 금정구 수림로85번길 53 (장전동)
# 10           인터플레이 PC방                         부산광역시 금정구 팔송로 36 (남산동)
# 11              엔터존PC방                  부산광역시 금정구 금강로279번길 81-6 (장전동)
# ...

# %%
busan_PCroom_jangjeon =df.loc[df["소재지"].str.contains("장전동", na=False)]
busan_PCroom_jangjeon
# Out:
#                    업소명                                       소재지          전화번호
# 5               렉없넷pc방                부산광역시 금정구 금정로149번길 8 (장전동)           NaN
# 6                 앤PC방                  부산광역시 금정구 부산대학로 59 (장전동)           NaN
# 7        OX PC방 부산대2호점            부산광역시 금정구 금정로68번길 22, 3층 (장전동)           NaN
# 9              사이버존PC방                부산광역시 금정구 수림로85번길 53 (장전동)           NaN
# 11              엔터존PC방             부산광역시 금정구 금강로279번길 81-6 (장전동)  051-583-3014
# 13                 쿨PC                   부산광역시 금정구 금강로 271 (장전동)           NaN
# 14    3POP PC(부산대 정문점)           부산광역시 금정구 부산대학로 49 (장전동, 오션프라자)           NaN
# 16             네버랜드PC방                부산광역시 금정구 장전로12번길 45 (장전동)           NaN
# 20               PC칸PC                부산광역시 금정구 부산대학로 62-1 (장전동)           NaN
# 21          노블PC카페 PC방         부산광역시 금정구 금정로68번길 42 (장전동,명제빌딩3층)           NaN
# 22              아이유PC방                  부산광역시 금정구 금정로 59-4 (장전동)  051-518-3596
# ...

# %% [markdown]
# # 노래방

# %%
busan_Sing = pd.read_csv('부산광역시 금정구_노래연습장 현황_20200518.csv', encoding='euc-kr' )
busan_Sing.rename({'상호명':'업소명', '영업소도로명소재지':'소재지','업종':'업종' }, axis='columns', inplace=True)
busan_Sing
# Out:
#                  업소명                                 소재지      업종
# 0            반도노래연습장             부산광역시 금정구 서동중심로 62 (서동)  노래연습장업
# 1            용궁노래연습장           부산광역시 금정구 금강로 680-1 (남산동)  노래연습장업
# 2          로얄박스노래연습장          부산광역시 금정구 서동로149번길 16 (서동)  노래연습장업
# 3            열창노래연습장          부산광역시 금정구 오시게로42번길 9 (부곡동)  노래연습장업
# 4            만남노래연습장         부산광역시 금정구 금정로233번길 49 (구서동)  노래연습장업
# ..               ...                                 ...     ...
# 189  락휴 코인노래연습장 부산대점  부산광역시 금정구 부산대학로 49, 오션프라자 3층 (장전동)  노래연습장업
# 190  락휴 코인노래연습장 구서역점          부산광역시 금정구 구서로 13, 2층 (구서동)  노래연습장업
# 191     코인싱어 동전노래연습장              부산광역시 금정구 남산로 15 (남산동)  노래연습장업
# 192   노래에반하다 동전노래연습장         부산광역시 금정구 금강로 338, 2층 (장전동)  노래연습장업
# 193    3.6.9 코인노래연습장         부산광역시 금정구 금강로 669, 2층 (남산동)  노래연습장업
#
# [194 rows x 3 columns]

# %%
busan_Sing_jangjeon = busan_Sing.loc[busan_Sing["소재지"].str.contains("장전동", na=False)]
busan_Sing_jangjeon
# Out:
#                  업소명                                     소재지      업종
# 7          밀레니엄노래연습장                부산광역시 금정구 부산대학로 57 (장전동)  노래연습장업
# 10           목화노래연습장              부산광역시 금정구 금강로391번길 5 (장전동)  노래연습장업
# 17           꺅 노래연습장               부산광역시 금정구 부산대학로 53  (장전동)  노래연습장업
# 22          마돈나노래연습장                부산광역시 금정구 금강로 268  (장전동)  노래연습장업
# 28           까치노래연습장               부산광역시 금정구 수림로49번길 3 (장전동)  노래연습장업
# 42          탈렌트노래연습장                부산광역시 금정구 금강로 251  (장전동)  노래연습장업
# 48           갈채노래연습장            부산광역시 금정구 금강로335번길 58  (장전동)  노래연습장업
# 52          카니발노래연습장             부산광역시 금정구 부산대학로 53-1  (장전동)  노래연습장업
# 56           소명노래연습장                부산광역시 금정구 금강로 299  (장전동)  노래연습장업
# 61          라이브노래연습장              부산광역시 금정구 금정로91번길 19 (장전동)  노래연습장업
# 69         발렌타인노래연습장             부산광역시 금정구 금정로68번길 34  (장전동)  노래연습장업
# 76         21세기노래연습장             부산광역시 금정구 금정로149번길 13 (장전동)  노래연습장업
# 81          토마토노래연습장                 부산광역시 금정구 금정로 57  (장전동)  노래연습장업
# ...

# %% [markdown]
# # 비디오감상실

# %%
busan_Video = pd.read_csv('부산광역시 금정구_비디오감상실업 현황_20200925.csv', encoding='euc-kr' )
busan_Video = busan_Video[['상호','영업소소재지(도로명)','전화번호']]
busan_Video.rename({'상호':'업소명', '영업소소재지(도로명)':'소재지','전화번호':'전화번호' }, axis='columns', inplace=True)
busan_Video
# Out:
#          업소명                          소재지           전화번호
# 0       윈시네마    부산광역시 금정구 부산대학로 62  (장전동)       582-4361
# 1   시네마월드2호점    부산광역시 금정구 부산대학로 48  (장전동)       514-2469
# 2       영화사랑  부산광역시 금정구 수림로85번길 59  (장전동)            NaN
# 3   JJ디지털영화관   부산광역시 금정구 장전로12번길 56 (장전동)       513-3690
# 4      성동비디오   부산광역시 금정구 장전로12번길 50 (장전동)       583-8577
# 5   with DVD       부산광역시 금정구 금정로 61 (장전동)       513-9500
# 6   BLUE DVD   부산광역시 금정구 장전로12번길 45 (장전동)       583-8112
# 7      클럽DVD   부산광역시 금정구 금정로60번길 24 (장전동)       514-5809
# 8      시네마클럽   부산광역시 금정구 금정로68번길 5  (장전동)       581-7288
# 9    아카데미프리죤     부산광역시 금정구 금강로 243  (장전동)  070-8826-7273
# 10       NaN                          NaN            NaN

# %%
busan_Video_jangjeon = busan_Video.loc[busan_Video["소재지"].str.contains("장전동", na=False)]
busan_Video_jangjeon
# Out:
#         업소명                          소재지           전화번호
# 0      윈시네마    부산광역시 금정구 부산대학로 62  (장전동)       582-4361
# 1  시네마월드2호점    부산광역시 금정구 부산대학로 48  (장전동)       514-2469
# 2      영화사랑  부산광역시 금정구 수림로85번길 59  (장전동)            NaN
# 3  JJ디지털영화관   부산광역시 금정구 장전로12번길 56 (장전동)       513-3690
# 4     성동비디오   부산광역시 금정구 장전로12번길 50 (장전동)       583-8577
# 5  with DVD       부산광역시 금정구 금정로 61 (장전동)       513-9500
# 6  BLUE DVD   부산광역시 금정구 장전로12번길 45 (장전동)       583-8112
# 7     클럽DVD   부산광역시 금정구 금정로60번길 24 (장전동)       514-5809
# 8     시네마클럽   부산광역시 금정구 금정로68번길 5  (장전동)       581-7288
# 9   아카데미프리죤     부산광역시 금정구 금강로 243  (장전동)  070-8826-7273
