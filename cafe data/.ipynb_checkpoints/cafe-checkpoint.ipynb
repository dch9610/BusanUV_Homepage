# %%
import pandas as pd
import csv

# %%
cafe = pd.read_csv('./cafe_1.csv', encoding='UTF-8')

# %%
cafe_North = cafe.loc[ cafe['lat'] > 35.23549829700748 ]

# %%
cafe_North = cafe_North.loc[cafe_North['lat'] <35.2369590588133 ]

# %%
cafe_North
# Out:
#          name clasificar middle clasificar    code small clasificar  \
# 1          산뽀         음식            커피점/카페  Q12A01      커피전문점/카페/다방
# 11     운죽정북카페         음식            커피점/카페  Q12A01      커피전문점/카페/다방
# 56  엠제이커피로스터리         음식            커피점/카페  Q12A01      커피전문점/카페/다방
# 74        105         음식            커피점/카페  Q12A01      커피전문점/카페/다방
# 76         백조         음식            커피점/카페  Q12A01      커피전문점/카페/다방
# 86    빈스에스프레소         음식            커피점/카페  Q12A01      커피전문점/카페/다방
# 87        엔커피         음식            커피점/카페  Q12A01      커피전문점/카페/다방
#
#                         addr        long        lat
# 1     부산광역시 금정구 부산대학로64번안길 2  129.085412  35.235921
# 11   부산광역시 금정구 부산대학로63번길 2-1  129.073322  35.236425
# 56       부산광역시 금정구 금정로 127-1  129.087490  35.236055
# 74    부산광역시 금정구 금강로279번길 111  129.083688  35.236819
# 76         부산광역시 금정구 금강로 308  129.086374  35.235596
# 86   부산광역시 금정구 금강로279번길 81-4  129.083715  35.235584
# 87  부산광역시 금정구 금강로279번길 81-10  129.083134  35.235635

# %%
cafe_front = cafe.loc[ cafe['long'] < 129.0865151753069 ]

# %%
cafe_sub = cafe.loc[ cafe['long'] > 129.0865151753069 ]

# %%
cafe_sub= cafe_sub.loc[ cafe_sub['lat'] > 35.22845667935142 ]

# %%
# Out:
#                      name clasificar middle clasificar    code  \
# 24                  할리스커피         음식            커피점/카페  Q12A01
# 35                   카페해뮴         음식            커피점/카페  Q12A01
# 36                  도르샐러드         음식            커피점/카페  Q12A01
# 37                     네오         음식            커피점/카페  Q12A01
# 43                   약속다방         음식            커피점/카페  Q12A01
# 44                  이솝페이블         음식            커피점/카페  Q12A01
# 46                   나무그늘         음식            커피점/카페  Q12A01
# 51               달콤커피부산대점         음식            커피점/카페  Q12A01
# 52   간단하지만특별한화피디Cafe봄봄장전점         음식            커피점/카페  Q12A01
# 53                  커피엔스타         음식            커피점/카페  Q12A01
# 55                   앤커피숍         음식            커피점/카페  Q12A01
# 56              엠제이커피로스터리         음식            커피점/카페  Q12A01
# 57                  자스민커피         음식            커피점/카페  Q12A01
# 58                     달콤         음식            커피점/카페  Q12A01
# ...

# %%
cafe = pd.read_csv('./cafe_1.csv', encoding='UTF-8')

# %%
cafe_long = cafe.loc[ cafe['long'] < 129.0865419180919 ]

# %%
cafe_sub = cafe.loc[ cafe['long'] > 129.0865419180919 ]

# %%
cafe_sub
# Out:
#                      name clasificar middle clasificar    code  \
# 24                  할리스커피         음식            커피점/카페  Q12A01
# 35                   카페해뮴         음식            커피점/카페  Q12A01
# 36                  도르샐러드         음식            커피점/카페  Q12A01
# 37                     네오         음식            커피점/카페  Q12A01
# 43                   약속다방         음식            커피점/카페  Q12A01
# 44                  이솝페이블         음식            커피점/카페  Q12A01
# 46                   나무그늘         음식            커피점/카페  Q12A01
# 51               달콤커피부산대점         음식            커피점/카페  Q12A01
# 52   간단하지만특별한화피디Cafe봄봄장전점         음식            커피점/카페  Q12A01
# 53                  커피엔스타         음식            커피점/카페  Q12A01
# 55                   앤커피숍         음식            커피점/카페  Q12A01
# 56              엠제이커피로스터리         음식            커피점/카페  Q12A01
# 57                  자스민커피         음식            커피점/카페  Q12A01
# 58                     달콤         음식            커피점/카페  Q12A01
# ...

# %%
cafe_front = cafe_long.loc[cafe_long['lat'] < 35.235496919369254 ]

# %%
cafe_front
# Out:
#       name clasificar middle clasificar    code small clasificar  \
# 0     자스민2         음식            커피점/카페  Q12A01      커피전문점/카페/다방
# 2       캣츠         음식            커피점/카페  Q12A01      커피전문점/카페/다방
# 3     커피느낌         음식            커피점/카페  Q12A01      커피전문점/카페/다방
# 4       베네         음식            커피점/카페  Q12A01      커피전문점/카페/다방
# 5    카페마운틴         음식            커피점/카페  Q12A01      커피전문점/카페/다방
# ..     ...        ...               ...     ...              ...
# 97   오직그대만         음식            커피점/카페  Q12A01      커피전문점/카페/다방
# 99    커피갤럽         음식            커피점/카페  Q12A01      커피전문점/카페/다방
# 101   카페드팽         음식            커피점/카페  Q12A01      커피전문점/카페/다방
# 102  마음연구소         음식            커피점/카페  Q12A05             사주카페
# 103    나우잇         음식            커피점/카페  Q12A01      커피전문점/카페/다방
#
#                        addr        long        lat
# 0    부산광역시 금정구 부산대학로64번길 43  129.084698  35.233439
# 2     부산광역시 금정구 부산대학로63번길 2  129.083856  35.232104
# ...

# %%
cafe_North = cafe_long.loc[cafe_long['lat'] > 35.235496919369254 ]

# %%
cafe_North
# Out:
#         name clasificar middle clasificar    code small clasificar  \
# 1         산뽀         음식            커피점/카페  Q12A01      커피전문점/카페/다방
# 11    운죽정북카페         음식            커피점/카페  Q12A01      커피전문점/카페/다방
# 74       105         음식            커피점/카페  Q12A01      커피전문점/카페/다방
# 76        백조         음식            커피점/카페  Q12A01      커피전문점/카페/다방
# 81   두커피로스터스         음식            커피점/카페  Q12A01      커피전문점/카페/다방
# 83      로제커피         음식            커피점/카페  Q12A01      커피전문점/카페/다방
# 86   빈스에스프레소         음식            커피점/카페  Q12A01      커피전문점/카페/다방
# 87       엔커피         음식            커피점/카페  Q12A01      커피전문점/카페/다방
# 95       더리터         음식            커피점/카페  Q12A01      커피전문점/카페/다방
# 96     릴리앤제이         음식            커피점/카페  Q12A01      커피전문점/카페/다방
# 98   다짐스터디카페         음식            커피점/카페  Q12A01      커피전문점/카페/다방
# 100       카페         음식            커피점/카페  Q12A01      커피전문점/카페/다방
#
#                          addr        long        lat
# ...
